# %%
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# # Hamiltonian

# %%
def hamiltonian(X0,t=0):
    return ([X0[1]/1.0,-5*(X0[0]-15)])
    
from scipy import integrate
t = np.linspace(0, 15,  100)              # time
#X0[0] is x, X[1] is p
X0 = np.array([1, 0])                     # initials conditions: 10 rabbits and 5 foxes
X, infodict = integrate.odeint(hamiltonian, X0, t, full_output=True)

# %%
plt.plot(X[:,0])
plt.show()
plt.plot(X[:,1])

# %%
def hamiltonian(X0,t=0):
    #print([X0[2]/1.0,X[3]/2.0,5*(X0[0]-X0[1]-15),-5*(X0[0]-X0[1]-15)])
    return ([X0[2]/1.0,X0[3]/1.0,-5*(X0[0]-X0[1]-15),5*(X0[0]-X0[1]-15)])
    
from scipy import integrate
t = np.linspace(0, 15,  100)              # time
#X0[0] is x, X[1] is p
X0 = np.array([0,0,5,3])                     # initials conditions: 10 rabbits and 5 foxes
print(X0)
X, infodict = integrate.odeint(hamiltonian, X0, t, full_output=True)
# Out:
# [0 0 5 3]

# %%
plt.plot(X[:,0])
plt.plot(X[:,1])
plt.show()
plt.plot(X[:,2])
plt.plot(X[:,3])
