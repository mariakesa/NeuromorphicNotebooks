# %%
import numpy as np
import matplotlib.pyplot as plt

C=1
R=1
tau=1

I=1.5

v_t=[]

v_0=0

v_rest=0

delta_t=0.1
v=v_0

threshold=1

for t in range(0,100):
    dvdt=(-(v-v_rest)+I*R)/tau
    v=v+dvdt*delta_t
    if v>threshold:
        v=0
    v_t.append(v)

plt.plot(v_t)
